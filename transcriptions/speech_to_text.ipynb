# %% [markdown]
# # Convertir de audo a texto (desde Youtube)

# %%
# !pip -qqq install git+https://github.com/openai/whisper.git pytube
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 81.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.1/153.1 kB 20.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 53.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 55.2 MB/s eta 0:00:00
# ...

# %%
import whisper
from pytube import YouTube

# %%
url = input('Pegar link y enter: ')
# Out:
# Pegar link y enter: https://www.youtube.com/watch?v=7jxIvSyp-fE

# %%
yt_url = YouTube(url)
audio_stream = yt_url.streams.filter(only_audio=True).first()
output_path = '/content'
filename = 'audio.mp3'
audio_stream.download(output_path=output_path, filename=filename)
print(f'El audio quedó en el colab en {output_path}/{filename}')
# Out:
# El audio quedó en el colab en /content/audio.mp3

# %% [markdown]
# ## Tamaño de Modelos
#
# Whisper tiene distintos tamaños de modelos, donde large tiene el mejor rendimiento para convertir de audio a texto, el inconveniente es que necesita harta GPU.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para utilizar otro modelo simplemente hay que cambiar el "large" con alguno que aparece en la imagen.

# %%
# !whisper 'audio.mp3' --model large --language Spanish
# Out:
# 100%|██████████████████████████████████████| 2.88G/2.88G [00:29<00:00, 103MiB/s]
# [00:00.080 --> 00:05.840]  Bueno amigos, ¿cómo están? Acá el Profe Joaco, estoy con mi amigo Lucas y con mi cámara Andri, ahí estamos listos.
# [00:06.220 --> 00:09.860]  Estamos haciendo una rutina, netamente trabajo correctivo.
# [00:10.280 --> 00:15.080]  ¿Qué significa trabajo correctivo? Son ejercicios como de grupos musculares más pequeños,
# [00:15.560 --> 00:21.220]  que tienen función de estabilizar y este trabajo correctivo es para mejorar quizás alguna lesión que ya tiene,
# [00:21.320 --> 00:27.200]  alguna dolencia, alguna molestia, o bien para prevenir también y fortalecer esos enlaces que suelen ser débiles.
# [00:27.200 --> 00:31.960]  En este caso nos vamos a centrar en los hombros y principalmente con mucho trabajo escapular,
# [00:32.160 --> 00:37.500]  puesto que la escápula tiene una función muy importante en todos los movimientos que tienen que ver con el tren superior,
# ...
